# %% [markdown]
# # Computer Vision - Segmentation

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
with open('cocostuff-10k-v1.1.json', 'r') as f:
    annotation = json.load(f)

# %%
annotation.keys()
# Out:
# dict_keys(['info', 'images', 'licenses', 'categories', 'annotations'])

# %%
import scipy.io
mat = scipy.io.loadmat('annotations/COCO_train2014_000000000077.mat')

# %%
img = cv.cvtColor(cv.imread('images/COCO_train2014_000000000077.jpg'), cv.COLOR_BGR2RGB)

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10, 10))
axes[0].imshow(mat['S'])
axes[1].imshow(img)

# %%
plt.imshow(img)
plt.imshow(mat['S'], alpha=0.5)
